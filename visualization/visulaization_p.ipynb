# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# seaborn is based in matplotlib
# adds a background color to the graphs
sns.set(color_codes=True) 

#tells python to actually display the graphs
# %matplotlib inline

# %%
# read data from csv
auto = pd.read_csv('Automobile.csv')
auto.head(2)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
#
# [2 rows x 26 columns]

# %%
auto['highway_mpg']
# Out:
# 0      27
# 1      27
# 2      26
# 3      30
# 4      22
#        ..
# 196    28
# 197    25
# 198    23
# 199    27
# 200    25
# Name: highway_mpg, Length: 201, dtype: int64

# %%
# correlation
# ranges between 1 to -1, positive means if one increses other values increases and vice-versa
auto.corr()
# Out:
#                    symboling  normalized_losses  wheel_base    length  \
# symboling           1.000000           0.474993   -0.535987 -0.365404
# normalized_losses   0.474993           1.000000    0.007815  0.103659
# wheel_base         -0.535987           0.007815    1.000000  0.876024
# length             -0.365404           0.103659    0.876024  1.000000
# width              -0.242423           0.153752    0.814507  0.857170
# height             -0.550160          -0.335476    0.590742  0.492063
# curb_weight        -0.233118           0.178547    0.782097  0.880665
# engine_size        -0.110581           0.174788    0.572027  0.685025
# bore               -0.146355           0.007498    0.495210  0.610324
# stroke              0.018373           0.062666    0.148239  0.116745
# compression_ratio  -0.182196          -0.120846    0.250313  0.159733
# horsepower          0.075287           0.276665    0.372607  0.577923
# ...

# %% [markdown]
# ### Plotting Univariate distributions
# - The most convenient way to take a quick look at a univariate distribution is distplot() function.
# - By default this will draw a histogram and fit a kernal density estimate (KDE)

# %%
sns.distplot(auto['highway_mpg']);

# %%
# we can turn off kde and display tick marks on the x-axis
sns.distplot(auto['highway_mpg'],kde=False,rug=True);

# %% [markdown]
# ### Plotting bivariate distributions
# - It can be useful to visualize the relationship between 2 variables.The easiest way is using      jointplot() function.
# - This creates a scatterplot of the 2 variables along with the histogram of each next to the appropiate axes.

# %%
sns.jointplot(auto['engine_size'],auto['horsepower']);

# %% [markdown]
# ### Hex Bin plots
# - we can make a hex bin plots that breaks the 2D area into hexagons and the no of points in each hexagon determines the color

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind="hex");

# %% [markdown]
# ### kernel density estimation
# - we can make a 2D estimation of the density

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind="kde");

# %% [markdown]
# ### Visulalizing pairwise relationships in a dataset
# - To plot multiple pairwise scatterplots in a dataset, we can use the pairplot() function.
# - This creates a matrix of axes and shows the relationship for each pair of columns in a Dataframe.
# - It also draws the histogram of each variable on the diagonal Axes.

# %%
sns.pairplot(auto[['normalized_losses','engine_size','horsepower']]);

# %% [markdown]
# ### Plotting with categorical data
# - In strip plot, the scatterplot points will usually overlap.This makes it difficult to see the full distribution of data.
# - One easy solution is to adjust the positions (only along the categorical axis) using jitter

# %%
sns.stripplot(auto['fuel_type'],auto['horsepower'],jitter=True);

# %% [markdown]
# - one different approach would be swarmplot() function, which positions each scatterplot on the categorical axis and overlapping points.

# %%
sns.swarmplot(auto['fuel_type'],auto['horsepower']);

# %% [markdown]
# ### BoxPlots
# - This plot shows the 3 Quartile values of the values of the distribution along with extreme values.
# - The whiskers extends to the points that lie within the 1.5 IQRs of the lower and upper quartile, and then observations that fall outside the range are displayed independently.

# %%
sns.boxplot(auto['number_of_doors'],auto['horsepower']);

# %%
# hue flag can be used for categorical analysis.
sns.boxplot(auto['number_of_doors'],auto['horsepower'],hue=auto['fuel_type']);

# %% [markdown]
# ### Bar Plots
# - we can plot the mean of a dataset, separated in categories using boxplot() function.
# - when there are multiple observations in each category, it uses bootstraping to compute a confidence interval around the estimate and plots that using error bars.
# - Bar plots starts from 0.

# %%
sns.barplot(auto['body_style'],auto['horsepower'],hue=auto['fuel_type']);

# %% [markdown]
# ### Special Case BarPlot
# - A special case for the bar plot is when you want to show the no. of observations in each category rather than computing the mean of a second variable.
# - This is similar to the histogram over a categorical , rather than quantitative variable.
# - countplot() function helps

# %%
sns.countplot(auto['body_style'],hue = auto['fuel_type']);

# %% [markdown]
# ### Point Plots
# - Show point estimates and confidence intervals using scatter plot glyphs.
# - A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
# - Point plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable. The lines that join each point from the same ``hue`` level allow interactions to be judged by differences in slope, which is easier for the eyes than comparing the heights of several groups of points or bars.

# %%
sns.pointplot(auto['body_style'],auto['horsepower'], hue = auto['number_of_doors']);

# %% [markdown]
# # Drawing multi-panel categorical plots
# ## catplot()
# - This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.
# - The ``kind`` parameter selects the underlying axes-level function to use:
#
# ### Categorical scatterplots:
#
# - :func:`stripplot` (with ``kind="strip"``; the default)
# - :func:`swarmplot` (with ``kind="swarm"``)
#
# ### Categorical distribution plots:
#
# - :func:`boxplot` (with ``kind="box"``)
# - :func:`violinplot` (with ``kind="violin"``)
# - :func:`boxenplot` (with ``kind="boxen"``)
#
# ### Categorical estimate plots:
#
# - :func:`pointplot` (with ``kind="point"``)
# - :func:`barplot` (with ``kind="bar"``)
# - :func:`countplot` (with ``kind="count"``)

# %%
# boxplot
sns.catplot(x='fuel_type',
            y='horsepower',
            hue='number_of_doors',
            col='drive_wheels',
            data=auto,
            kind='box');

# %%
# bar plot
sns.catplot(x='fuel_type',
            y='horsepower',
            hue='number_of_doors',
            col='drive_wheels',
            data=auto,
            kind='bar');

# %%
# point plot
sns.catplot(x='fuel_type',
            y='horsepower',
            hue='number_of_doors',
            col='drive_wheels',
            data=auto,
            kind='point');

# %%
# count plot
sns.catplot(x='fuel_type',
            hue='number_of_doors',
            col='drive_wheels',
            data=auto,
            kind='count');

# %%
# violin plot
sns.catplot(x='fuel_type',
            y='horsepower',
            hue='number_of_doors',
            col='drive_wheels',
            data=auto,
            kind='violin');

# %%
# strip plot
sns.catplot(x='fuel_type',
            y='horsepower',
            hue='number_of_doors',
            col='drive_wheels',
            data=auto,
            kind='strip');

# %% [markdown]
# ### Functions to draw linear regressions models

# %%
sns.lmplot(y="horsepower",x="engine_size",data=auto);

# %%
sns.lmplot(y="horsepower",x="engine_size",hue = 'fuel_type',data=auto);
